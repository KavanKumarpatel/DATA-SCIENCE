# %%
import pandas as pd

# %%
data = {"a":[1,2,3,4,5],
       "b":[4,5,56,6,7],
       "c":["kavan","krish","navin","dhynam","keval"]}

# %%
data
# Out:
# {'a': [1, 2, 3, 4, 5],
#  'b': [4, 5, 56, 6, 7],
#  'c': ['kavan', 'krish', 'navin', 'dhynam', 'keval']}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    a   b       c
# 0  1   4   kavan
# 1  2   5   krish
# 2  3  56   navin
# 3  4   6  dhynam
# 4  5   7   keval

# %%
df.set_index('a',inplace=True)

# %%
df
# Out:
#     b       c
# a
# 1   4   kavan
# 2   5   krish
# 3  56   navin
# 4   6  dhynam
# 5   7   keval

# %%
df.reset_index()
# Out:
#    a   b       c
# 0  1   4   kavan
# 1  2   5   krish
# 2  3  56   navin
# 3  4   6  dhynam
# 4  5   7   keval

# %%
data = {"a":[1,2,3,4,5],
       "b":[4,5,56,6,7],
       "c":["kavan","krish","navin","dhynam","keval"]}
df1=pd.DataFrame(data,index = ['a','b','c','d','e'])

# %%
df1
# Out:
#    a   b       c
# a  1   4   kavan
# b  2   5   krish
# c  3  56   navin
# d  4   6  dhynam
# e  5   7   keval

# %%
df1.reindex(['b','c','d','e','a'])
# Out:
#    a   b       c
# b  2   5   krish
# c  3  56   navin
# d  4   6  dhynam
# e  5   7   keval
# a  1   4   kavan

# %%
df1
# Out:
#    a   b       c
# a  1   4   kavan
# b  2   5   krish
# c  3  56   navin
# d  4   6  dhynam
# e  5   7   keval

# %%
df.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x000001874B444F20>

# %%
for i in df.iterrows():
    print(i)
# Out:
# (1, b        4
# c    kavan
# Name: 1, dtype: object)
# (2, b        5
# c    krish
# Name: 2, dtype: object)
# (3, b       56
# c    navin
# Name: 3, dtype: object)
# (4, b         6
# c    dhynam
# Name: 4, dtype: object)
# (5, b        7
# c    keval
# Name: 5, dtype: object)

# %%
df1
# Out:
#    a   b       c
# a  1   4   kavan
# b  2   5   krish
# c  3  56   navin
# d  4   6  dhynam
# e  5   7   keval

# %%
for i,j in df.iterrows():
    print( j)
# Out:
# b        4
# c    kavan
# Name: 1, dtype: object
# b        5
# c    krish
# Name: 2, dtype: object
# b       56
# c    navin
# Name: 3, dtype: object
# b         6
# c    dhynam
# Name: 4, dtype: object
# b        7
# c    keval
# Name: 5, dtype: object

# %%
df1
# Out:
#    a   b       c
# a  1   4   kavan
# b  2   5   krish
# c  3  56   navin
# d  4   6  dhynam
# e  5   7   keval

# %%
for i  in df1.iteritems():
    print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19068\520842960.py in ?()
# ----> 1 for i  in df1.iteritems():
#       2     print(i)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'iteritems'

# %%
 for col_name,column in df1.iteritems():
        print(col_name , column)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19068\3735503011.py in ?()
# ----> 1 for col_name,column in df1.iteritems():
#       2        print(col_name , column)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'iteritems'

# %%
df1
# Out:
#    a   b       c
# a  1   4   kavan
# b  2   5   krish
# c  3  56   navin
# d  4   6  dhynam
# e  5   7   keval

# %%
df1['a']
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: a, dtype: int64

# %%
list(df1['a'])
# Out:
# [1, 2, 3, 4, 5]

# %%
[ i for i in df1['a']]
# Out:
# [1, 2, 3, 4, 5]

# %%
df1
# Out:
#    a   b       c
# a  1   4   kavan
# b  2   5   krish
# c  3  56   navin
# d  4   6  dhynam
# e  5   7   keval

# %%
def test(x):
    return x.sum()
df1.apply(test, axis=0)
# Out:
# a                            15
# b                            78
# c    kavankrishnavindhynamkeval
# dtype: object

# %%
df1
# Out:
#    a   b       c
# a  1   4   kavan
# b  2   5   krish
# c  3  56   navin
# d  4   6  dhynam
# e  5   7   keval

# %%
df2 = df1[['a','b']]

# %%
df2
# Out:
#    a   b
# a  1   4
# b  2   5
# c  3  56
# d  4   6
# e  5   7

# %%
df2.applymap(lambda x:x**2)
# Out:
#     a     b
# a   1    16
# b   4    25
# c   9  3136
# d  16    36
# e  25    49

# %%
df1
# Out:
#    a   b       c
# a  1   4   kavan
# b  2   5   krish
# c  3  56   navin
# d  4   6  dhynam
# e  5   7   keval

# %%
df
# Out:
#     b       c
# a
# 1   4   kavan
# 2   5   krish
# 3  56   navin
# 4   6  dhynam
# 5   7   keval

# %%
df.sort_values('c')
# Out:
#     b       c
# a
# 4   6  dhynam
# 1   4   kavan
# 5   7   keval
# 2   5   krish
# 3  56   navin

# %%
df.sort_values('b')
# Out:
#     b       c
# a
# 1   4   kavan
# 2   5   krish
# 4   6  dhynam
# 5   7   keval
# 3  56   navin

# %%
df.sort_values('b','c')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df.sort_values('b','c')
#
# TypeError: DataFrame.sort_values() takes 2 positional arguments but 3 were given

# %%
df.sort_index(ascending = False)
# Out:
#     b       c
# a
# 5   7   keval
# 4   6  dhynam
# 3  56   navin
# 2   5   krish
# 1   4   kavan

# %%
pd.set_option("display.max_colwidth",500)
df3 =pd.DataFrame({'Desc':["this is Data Science master course for python Devloper . thus Data Science is the most demanding domain for future aspect."]})

# %%
df3
# Out:
#                                                                                                                          Desc
# 0  this is Data Science master course for python Devloper . thus Data Science is the most demanding domain for future aspect.

# %%
"""Agar hamare paas bohot sara data hogaya tab wo automatically nai dikhayega hame set option karna padega display ke sath"""
# Out:
# 'Agar hamare paas bohot sara data hogaya tab wo automatically nai dikhayega hame set option karna padega display ke sath'

# %%
df3
# Out:
#                                                                                                                          Desc
# 0  this is Data Science master course for python Devloper . thus Data Science is the most demanding domain for future aspect.

# %%
pd.set_option("display.max_colwidth",20)
df4=pd.DataFrame({"Intro":["namaskaram! ,i,m Kavan Patel cururently pursuing 4th year B.E in LDRP institute . i'm Java Devloper. My expertise is spring ,sevlet , jdbc. here i'm practice codeing for collage or campus placement . This is not for sure about my capablity because i don't enough code for any suitable position in it company."]})

# %%
df4
# Out:
#                  Intro
# 0  namaskaram! ,i,m...

# %%
pd.set_option("display.max_colwidth",500)
df4=pd.DataFrame({"Intro":["namaskaram! ,i,m Kavan Patel cururently pursuing 4th year B.E in LDRP institute . i'm Java Devloper. My expertise is spring ,sevlet , jdbc. here i'm practice codeing for collage or campus placement . This is not for sure about my capablity because i don't enough code for any suitable position in it company."]})

# %%
df4
# Out:
#                                                                                                                                                                                                                                                                                                                   Intro
# 0  namaskaram! ,i,m Kavan Patel cururently pursuing 4th year B.E in LDRP institute . i'm Java Devloper. My expertise is spring ,sevlet , jdbc. here i'm practice codeing for collage or campus placement . This is not for sure about my capablity because i don't enough code for any suitable position in it company.

# %%
df4=pd.DataFrame({"Intro":["namaskaram! ,i,m Kavan Patel cururently pursuing 4th year B.E in LDRP institute . i'm Java Devloper. My expertise is spring ,sevlet , jdbc. here i'm practice codeing for collage or campus placement . This is not for sure about my capablity because i don't enough code for any suitable position in it company.","my hobby is do yoga , learning , analysis any thing , think any situation ","My Favourtite color is blue ."]})

# %%
df4
# Out:
#                                                                                                                                                                                                                                                                                                                   Intro
# 0  namaskaram! ,i,m Kavan Patel cururently pursuing 4th year B.E in LDRP institute . i'm Java Devloper. My expertise is spring ,sevlet , jdbc. here i'm practice codeing for collage or campus placement . This is not for sure about my capablity because i don't enough code for any suitable position in it company.
# 1                                                                                                                                                                                                                                            my hobby is do yoga , learning , analysis any thing , think any situation
# ...

# %%
df4['len']=df4['Intro'].apply(len)

# %%
df4
# Out:
#                                                                                                                                                                                                                                                                                                                   Intro  \
# 0  namaskaram! ,i,m Kavan Patel cururently pursuing 4th year B.E in LDRP institute . i'm Java Devloper. My expertise is spring ,sevlet , jdbc. here i'm practice codeing for collage or campus placement . This is not for sure about my capablity because i don't enough code for any suitable position in it company.
# 1                                                                                                                                                                                                                                            my hobby is do yoga , learning , analysis any thing , think any situation
# ...

# %%
t = "i use to tech Data Science"
len(t.split())
# Out:
# 6

# %%
df4['word_count'] = df4['Intro'].apply(lambda x:len(x.split()))

# %%
df4
# Out:
#                                                                                                                                                                                                                                                                                                                   Intro  \
# 0  namaskaram! ,i,m Kavan Patel cururently pursuing 4th year B.E in LDRP institute . i'm Java Devloper. My expertise is spring ,sevlet , jdbc. here i'm practice codeing for collage or campus placement . This is not for sure about my capablity because i don't enough code for any suitable position in it company.
# 1                                                                                                                                                                                                                                            my hobby is do yoga , learning , analysis any thing , think any situation
# ...

# %%
df
# Out:
#     b       c
# a
# 1   4   kavan
# 2   5   krish
# 3  56   navin
# 4   6  dhynam
# 5   7   keval

# %%
df4['a'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[103], line 1
# ...

# %%
df['a'].median()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[102], line 1
# ...

# %%
df11 = pd.DataFrame({"key1":[1,2,3,4,5,6],
                    "key2":[34,45,56,23,33,123],
                    "key3":[345,34,234,324,423,435]}
                   )

# %%
df11
# Out:
#    key1  key2  key3
# 0     1    34   345
# 1     2    45    34
# 2     3    56   234
# 3     4    23   324
# 4     5    33   423
# 5     6   123   435

# %%
df11.index['a','b','c','d','e','f']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 df11.index['a','b','c','d','e','f']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:924, in RangeIndex.__getitem__(self, key)
#     917 elif is_scalar(key):
#     918     raise IndexError(
#     919         "only integers, slices (`:`), "
#     920         "ellipsis (`...`), numpy.newaxis (`None`) "
#     921         "and integer or boolean "
#     922         "arrays are valid indices"
#     923     )
# --> 924 return super().__getitem__(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5196, in Index.__getitem__(self, key)
#    5193     else:
#    5194         key = np.asarray(key, dtype=bool)
# -> 5196 result = getitem(key)
#    5197 # Because we ruled out integer above, we always get an arraylike here
#    5198 if result.ndim > 1:
#
# ...

# %%
df11.set_index('a',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19068\3918817650.py in ?()
# ----> 1 df11.set_index('a',inplace=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['a'] are in the columns"

# %%
df11=pd.DataFrame(data,index = ['0','1','2','3','4'])

# %%
df11
# Out:
#    a   b       c
# 0  1   4   kavan
# 1  2   5   krish
# 2  3  56   navin
# 3  4   6  dhynam
# 4  5   7   keval

# %%
df11['a'].median()
# Out:
# 3.0

# %%
df11['a'].mean()
# Out:
# 3.0

# %%
df11['a'].mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: a, dtype: int64

# %%
df11['a'].std()
# Out:
# 1.5811388300841898

# %%
df11['a'].sum()
# Out:
# 15

# %%
df11['a'].min()
# Out:
# 1

# %%
df11['a'].max()
# Out:
# 5

# %%
df11['a'].var()
# Out:
# 2.5

# %%
df12=pd.DataFrame({'a':[3,4,5,2,1,3,4,5,6]})

# %%
df12['a'].rolling(window =1).mean()
# Out:
# 0    3.0
# 1    4.0
# 2    5.0
# 3    2.0
# 4    1.0
# 5    3.0
# 6    4.0
# 7    5.0
# 8    6.0
# Name: a, dtype: float64

# %%
df12['a'].rolling(window =2).mean()
# Out:
# 0    NaN
# 1    3.5
# 2    4.5
# 3    3.5
# 4    1.5
# 5    2.0
# 6    3.5
# 7    4.5
# 8    5.5
# Name: a, dtype: float64

# %%
df12['a'].rolling(window =3).mean()
# Out:
# 0         NaN
# 1         NaN
# 2    4.000000
# 3    3.666667
# 4    2.666667
# 5    2.000000
# 6    2.666667
# 7    4.000000
# 8    5.000000
# Name: a, dtype: float64

# %%
df12
# Out:
#    a
# 0  3
# 1  4
# 2  5
# 3  2
# 4  1
# 5  3
# 6  4
# 7  5
# 8  6

# %%
df11['a'].cumsum()
# Out:
# 0     1
# 1     3
# 2     6
# 3    10
# 4    15
# Name: a, dtype: int64

# %%
#python pandas = Date  Functionality
date=pd.date_range(start = '2023-04-23',end = '2023-06-23')

# %%
date
# Out:
# DatetimeIndex(['2023-04-23', '2023-04-24', '2023-04-25', '2023-04-26',
#                '2023-04-27', '2023-04-28', '2023-04-29', '2023-04-30',
#                '2023-05-01', '2023-05-02', '2023-05-03', '2023-05-04',
#                '2023-05-05', '2023-05-06', '2023-05-07', '2023-05-08',
#                '2023-05-09', '2023-05-10', '2023-05-11', '2023-05-12',
#                '2023-05-13', '2023-05-14', '2023-05-15', '2023-05-16',
#                '2023-05-17', '2023-05-18', '2023-05-19', '2023-05-20',
#                '2023-05-21', '2023-05-22', '2023-05-23', '2023-05-24',
#                '2023-05-25', '2023-05-26', '2023-05-27', '2023-05-28',
#                '2023-05-29', '2023-05-30', '2023-05-31', '2023-06-01',
#                '2023-06-02', '2023-06-03', '2023-06-04', '2023-06-05',
#                '2023-06-06', '2023-06-07', '2023-06-08', '2023-06-09',
#                '2023-06-10', '2023-06-11', '2023-06-12', '2023-06-13',
# ...

# %%
df_date = pd.DataFrame({'date':date})

# %%
df_date
# Out:
#          Date
# 0  2023-04-23
# 1  2023-04-24
# 2  2023-04-25
# 3  2023-04-26
# 4  2023-04-27
# ..        ...
# 57 2023-06-19
# 58 2023-06-20
# 59 2023-06-21
# 60 2023-06-22
# 61 2023-06-23
#
# [62 rows x 1 columns]
