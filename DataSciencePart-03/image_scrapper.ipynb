# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen as ureq
import logging 
#import pymongo
import os

# %%
save_dir="images/"

if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
kuquery="kavan kumar"

response=request.get{f"https://www.bing.com/images/search?q={query}view=detailV2&ccid=8rZ%2fvkKs&id=9338A24BE21E8A4D0B86109E44D308DD51202218&thid=OIP.8rZ_vkKs47FfOVWoj5jq3gHaH9&mediaurl=https%3a%2f%2ftaxila.in%2fimg%2fstaff%2flarge%2fsudhanshu-kumar.png&exph=537&expw=500&q=sudhanshu+mar&simid=608034273116506612&FORM=IRPRST&ck=30BF9A3AFA18B03A472E88C9116B4717&selectedIndex=3&itb=1&ajaxhist=0&ajaxserp=0"}
# Out:
#   Cell In[4], line 3
#     response=request.get{f"https://www.bing.com/images/search?q={query}view=detailV2&ccid=8rZ%2fvkKs&id=9338A24BE21E8A4D0B86109E44D308DD51202218&thid=OIP.8rZ_vkKs47FfOVWoj5jq3gHaH9&mediaurl=https%3a%2f%2ftaxila.in%2fimg%2fstaff%2flarge%2fsudhanshu-kumar.png&exph=537&expw=500&q=sudhanshu+mar&simid=608034273116506612&FORM=IRPRST&ck=30BF9A3AFA18B03A472E88C9116B4717&selectedIndex=3&itb=1&ajaxhist=0&ajaxserp=0"}
#                         ^
# SyntaxError: invalid syntax

# %%
soup=BeautifulSoup(response.content,'html.parser')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 soup=BeautifulSoup(response.content,'html.parser')
#
# NameError: name 'response' is not defined

# %%
images_tags=soup.find_all("img")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 images_tags=soup.find_all("img")
#
# NameError: name 'soup' is not defined

# %%
len(images_tags)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 len(images_tags)
#
# NameError: name 'images_tags' is not defined

# %%
del image_tags[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 del image_tags[0]
#
# NameError: name 'image_tags' is not defined

# %%
images_tags[]
# Out:
#   Cell In[10], line 1
#     images_tags[]
#                 ^
# SyntaxError: invalid syntax

# %%
img_data_mongo=[]

for i in images_tags:
    image_url=i["src"]
    
    image_data=request.get(image_url).content
    mydict={"index":imageurl,"image":image_data}
    img_data_mongo.append(mydict)
    with open(os,path.join(save_dir,f"{query}_{image_tags.index(i)}.jpg","wb")) as f:
        f.write(image_data)
        
#client=pymongo.Mongoclient("mongodb+srv://pwskills:pwskills@cluster0.in0bt5m.mongodb.net/?retryWrites=true&w=majority")
#db=client['image_scrap']
#coll_image=db["image_scrap"]
#coll_image.insert_many(img_data_mongo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 img_data_mongo=[]
# ----> 3 for i in images_tags:
#       4     image_url=i["src"]
#       6     image_data=request.get(image_url).content
#
# NameError: name 'images_tags' is not defined
