# %%
l=[1,2,3,45,6,7]
l1=[]
for i in l:
    l1.append(i**2)

# %%
l1
# Out:
# [1, 4, 9, 2025, 36, 49]

# %%
l
# Out:
# [1, 2, 3, 45, 6, 7]

# %%
[i**2 for i in l]
# Out:
# [1, 4, 9, 2025, 36, 49]

# %%
[ i for i  in l if i%2 == 0]
# Out:
# [2, 6]

# %%
l1=['kavan','pwskills','kumar','nimisha']

# %%
[i.upper() for i in l1]
# Out:
# ['KAVAN', 'PWSKILLS', 'KUMAR', 'NIMISHA']

# %%
l=[2,3,4,5,55]

# %%
list(i**2 for i in l)
# Out:
# [4, 9, 16, 25, 3025]

# %%
d={'key1':1,'key2':2,'key3':3,'key4':4}

# %%
{k:v**2 for k,v in d.items()}
# Out:
# {'key1': 1, 'key2': 4, 'key3': 9, 'key4': 16}

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3), ('key4', 4)])

# %%
d
# Out:
# {'key1': 1, 'key2': 2, 'key3': 3, 'key4': 4}

# %%
{k : v for k, v in d.items() if v>1}
# Out:
# {'key2': 2, 'key3': 3, 'key4': 4}
