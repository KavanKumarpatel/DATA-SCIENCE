# %%
a=10

# %%
a/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 a/0
#
# ZeroDivisionError: division by zero

# %%
f=open("test11.txt",'r')
print("this is my print")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 f=open("test11.txt",'r')
#       2 print("this is my print")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test11.txt'

# %%
#python sequentially mood me execution karta hain 
#aur ye file exists nai hain issliye error aa raha hain read karate issliye

# %%
try :
    
    f=open("test11.txt","r")
    f.write("write into my file")
    f.close()
    
except Exception as e:
    print("This is my Except block", e)
a=56*4
b=98+34
print(a,b)
# Out:
# This is my Except block [Errno 2] No such file or directory: 'test11.txt'
# 224 132

# %%
try :
    
    f=open("test88.txt","w")
    f.write("write into my file")
    f.close()
    
except Exception as e:
    print("This is my Except block", e)

else :
    f.close()
    print("This will be execute once your try will execute without error")
# Out:
# This will be execute once your try will execute without error

# %%
#else cod etabhi execute hoga jab try block sucessfully execute hua ho
"""to jab exception vala block execute na ho tab else wala block execute hota hain"""
# Out:
# 'to jab exception vala block execute na ho tab else wala block execute hota hain'

# %%
try :
    
    f=open("test156.txt","r")
    f.write("write into my file")
    f.close()
    
except Exception as e:
    print("This is my Except block", e)

else :
    f.close()
    print("This will be execute once your try will execute without error")
# Out:
# This is my Except block [Errno 2] No such file or directory: 'test156.txt'

# %%
try:
    f=open("test22.txt","w")
    f=write("write Something")
finally :
    print("finally will execute itself in any situation")
# Out:
# finally will execute itself in any situation
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 try:
#       2     f=open("test22.txt","w")
# ----> 3     f=write("write Something")
#       4 finally :
#       5     print("finally will execute itself in any situation")
#
# NameError: name 'write' is not defined

# %%
#finally hamesha execute hoga koi bhi situation me
