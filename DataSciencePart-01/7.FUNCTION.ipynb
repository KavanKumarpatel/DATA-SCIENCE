# %%
print("this is my print function")
# Out:
# this is my print function

# %%
l=[45,2,434]

# %%
len(l)
# Out:
# 3

# %%
type(l)
# Out:
# list

# %%
def test():
    pass

# %%
def test1():
    print("this is my very very first function")

# %%
test1()
# Out:
# this is my very very first function

# %%
test1()+"kavan"
# Out:
# this is my very very first function
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 test1()+"kavan"
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'str'

# %%
def test2():
    return 'this is my first return'

# %%
test2()
# Out:
# 'this is my first return'

# %%
test2()+" kavan"
# Out:
# 'this is my first return kavan'

# %%
def test3():
    return "kavan",34,54.45,[4,5,56,5]

# %%
test3()
# Out:
# ('kavan', 34, 54.45, [4, 5, 56, 5])

# %%
a,b,c,d=test3()

# %%
a
# Out:
# 'kavan'

# %%
b
# Out:
# 34

# %%
c
# Out:
# 54.45

# %%
d
# Out:
# [4, 5, 56, 5]

# %%
def test4():
    a=5+6/7
    return a

# %%
test4()
# Out:
# 5.857142857142857

# %%
def test5(a,b,c):
    d=a+b/c
    return d

# %%
test5()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 test5()
#
# TypeError: test5() missing 3 required positional arguments: 'a', 'b', and 'c'

# %%
test5(3,4,6)
# Out:
# 3.6666666666666665

# %%
def test6(a,b):
    return a+b

# %%
test6(3,67)
# Out:
# 70

# %%
test6("kavan","kumar")
# Out:
# 'kavankumar'

# %%
test6([45,234,5],[76,84])
# Out:
# [45, 234, 5, 76, 84]

# %%
l=[1,2,3,4,"kavan","kumar",[1,2,3,4,5]]

# %%
l1=[]
for i in l:
    if type(i) == int or type(i) == float:
        l1.append(i)

# %%
l1
# Out:
# [1, 2, 3, 4]

# %%
def test7(l):
    l1=[]
    for i in l:
        if type(i) == int or type(i)==float:
            l1.append(i)
    return l1

# %%
test7(l)
# Out:
# [1, 2, 3, 4]

# %%
l
# Out:
# [1, 2, 3, 4, 'kavan', 'kumar', [1, 2, 3, 4, 5]]

# %%
def test8(a):
    l=[]
    for i in a:
        if type(i)== list:
            for j in i:
                l.append(j)
        else:
            if type(i)== int or type(i)==float:
                l.append(i)
    return l

# %%
test8(l)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4, 5]

# %%
l
# Out:
# [1, 2, 3, 4, 'kavan', 'kumar', [1, 2, 3, 4, 5]]

# %%
test8()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 test8()
#
# TypeError: test8() missing 1 required positional argument: 'a'

# %%
def test9(a):
    '''this is  my function to extract num data from list'''
    l=[]
    for i in a:
        if type(i)== list:
            for j in i:
                l.append(j)
        else:
            if type(i)== int or type(i)==float:
                l.append(i)
    return l

# %%
test9()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 test9()
#
# TypeError: test9() missing 1 required positional argument: 'a'

# %%
def test10(a,b):
    return a+b

# %%
def test11(*args):
    return args

# %%
type(test11())
# Out:
# tuple

# %%
test11(1,2,3)
# Out:
# (1, 2, 3)

# %%
test11()
# Out:
# ()

# %%
test11(1,2,3,"kavan","kumar",[2,3,434,43])
# Out:
# (1, 2, 3, 'kavan', 'kumar', [2, 3, 434, 43])

# %%
def test12(*kavan):
     return kavan

# %%
test12(12,3,234,34)
# Out:
# (12, 3, 234, 34)

# %%
def test13(*args,a):
    return args,a

# %%
test13(1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 test13(1,2,3,4)
#
# TypeError: test13() missing 1 required keyword-only argument: 'a'

# %%
test13(1,2,3,4,a=23)
# Out:
# ((1, 2, 3, 4), 23)

# %%
def test14(c,d,a=23,b=1):
    return a,b,c,d

# %%
test14()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 test14()
#
# TypeError: test14() missing 2 required positional arguments: 'c' and 'd'

# %%
test14(3,4)
# Out:
# (23, 1, 3, 4)

# %%
test14(23,4,a=473,b=48375)
# Out:
# (473, 48375, 23, 4)

# %%
def test15(**kwargs):
    return kwargs

# %%
test15()
# Out:
# {}

# %%
type(test15())
# Out:
# dict

# %%
test15(a=[1,2,3,4,5],b='kavan',c=34.435)
# Out:
# {'a': [1, 2, 3, 4, 5], 'b': 'kavan', 'c': 34.435}
