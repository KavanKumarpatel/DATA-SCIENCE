# %%
t=(2,3,4,5,"kavan",445.4543,False,45+6j,[54,3.45])

# %%
t
# Out:
# (2, 3, 4, 5, 'kavan', 445.4543, False, (45+6j), [54, 3.45])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 9

# %%
t[0]
# Out:
# 2

# %%
t[-1]
# Out:
# [54, 3.45]

# %%
t[::-1]
# Out:
# ([54, 3.45], (45+6j), False, 445.4543, 'kavan', 5, 4, 3, 2)

# %%
list=[34,"nimu","subvar",9+6j]

# %%
list[0]='bachhu'

# %%
list
# Out:
# ['bachhu', 'nimu', 'subvar', (9+6j)]

# %%
t
# Out:
# (2, 3, 4, 5, 'kavan', 445.4543, False, (45+6j), [54, 3.45])

# %%
t[0]='nimu'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 t[0]='nimu'
#
# TypeError: 'tuple' object does not support item assignment

# %%
t[::-1]
# Out:
# ([54, 3.45], (45+6j), False, 445.4543, 'kavan', 5, 4, 3, 2)

# %%
#this is not mutable it is create new objet.

# %%
#tuple has only two function count and index

# %%
t.count(5)
# Out:
# 1

# %%
t.index(False)
# Out:
# 6

# %%
# here strated set

# %%
s1={}

# %%
type(s1)
# Out:
# dict

# %%
s2={2,3,4,5}

# %%
type(s2)
# Out:
# set

# %%
s3={432,34,"kavan",45+7j,[4,5,6]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 s3={432,34,"kavan",45+7j,[4,5,6]}
#
# TypeError: unhashable type: 'list'

# %%
s4={45,67556,"nimisha",5+9j,(6,7,4)}

# %%
s4
# Out:
# {(5+9j), (6, 7, 4), 45, 67556, 'nimisha'}

# %%
s5={2,3,4,3,3,456,23,4,2,4,2,1,3,4,5,"nimisha","kavan","nimisha"}

# %%
s5
# Out:
# {1, 2, 23, 3, 4, 456, 5, 'kavan', 'nimisha'}

# %%
l5=[2,3,4,3,3,456,23,4,2,4,2,1,3,4,5,"nimisha","kavan","nimisha"]

# %%
l5=set(l5)

# %%
l5
# Out:
# {1, 2, 23, 3, 4, 456, 5, 'kavan', 'nimisha'}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 l5=list(set(l5))
#
# TypeError: 'list' object is not callable
