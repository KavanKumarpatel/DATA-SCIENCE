# %%
1+1
# Out:
# 2

# %%
5*5
# Out:
# 25

# %%
a=9

# %%
b=78

# %%
a+b
# Out:
# 87

# %%
a
# Out:
# 9

# %%
type(a)
# Out:
# int

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
 type(b)
# Out:
# int

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
c='tirth'

# %%
print(type(c))
# Out:
# <class 'str'>

# %%
c=495.8435

# %%
print(type(c))
# Out:
# <class 'float'>

# %%
a=34
b=67.5

# %%
print(a/b)
# Out:
# 0.5037037037037037

# %%
print(b/a)
# Out:
# 1.9852941176470589

# %%
c=a/b
print(c)
# Out:
# 0.5037037037037037

# %%
c=b/a
print(c)
# Out:
# 1.9852941176470589

# %%
p=True
print(type(p))
# Out:
# <class 'bool'>

# %%
 True+True
# Out:
# 2

# %%
True+False
# Out:
# 1

# %%
True*False
# Out:
# 0

# %%
False/True
# Out:
# 0.0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
v=5+8j
print(type(v))
# Out:
# <class 'complex'>

# %%
c=5i+6j
print(type(c))
# Out:
#   Cell In[28], line 1
#     c=5i+6j
#       ^
# SyntaxError: invalid decimal literal

# %%
 v.real
# Out:
# 5.0

# %%
v.imag
# Out:
# 8.0

# %%
print("My name is Kavan")
# Out:
# My name is Kavan

# %%
print(v)
# Out:
# (5+8j)

# %%
print v
# Out:
#   Cell In[33], line 1
#     print v
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
s="pwskills"

# %%
type(s)
# Out:
# str

# %%
print(s[0])
# Out:
# p

# %%
s[4:9]
# Out:
# 'ills'

# %%
s[0:8:2]
# Out:
# 'psil'

# %%
s[0:4:1]
# Out:
# 'pwsk'

# %%
s[:-38:-1]
# Out:
# 'sllikswp'

# %%
s[2:8:2]
# Out:
# 'sil'

# %%
 s.find('i')
# Out:
# 4

# %%
s.
# Out:
#   Cell In[47], line 1
#     s.
#       ^
# SyntaxError: invalid syntax

# %%
print("this is my first string")
# Out:
# this is my first string

# %%
s1="this is my  first string"

# %%
s1.count("t")
# Out:
# 3

# %%
s1.find("r")
# Out:
# 14

# %%
  4+4
# Out:
# 8

# %%
a='this is my first program '

# %%
a.count('a')
# Out:
# 1

# %%
a.find("s")
# Out:
# 3

# %%
""""this is my multiple comment 
  this is my second line 
      is my third line """
# Out:
# '"this is my multiple comment \n  this is my second line \n      is my third line '

# %%
#this is single line comment

# %%
a=['1','2','3']

# %%
print(a)
# Out:
# ['1', '2', '3']

# %%
a
# Out:
# ['1', '2', '3']

# %%
l=[45,546,54.565,"kavan",True,False,5+6j]

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
l[0]
# Out:
# 45

# %%
l[0:6:2]
# Out:
# [45, 54.565, True]

# %%
l[2]
# Out:
# 54.565

# %%
l[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 l[7]
#
# IndexError: list index out of range

# %%
l[45]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 l[45]
#
# IndexError: list index out of range

# %%
l.find.imag
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 l.find.imag
#
# AttributeError: 'list' object has no attribute 'find'

# %%
l.find(real)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 l.find(real)
#
# AttributeError: 'list' object has no attribute 'find'

# %%
l
# Out:
# [45, 546, 54.565, 'kavan', True, False, (5+6j)]

# %%
l[0:3]
# Out:
# [45, 546, 54.565]

# %%
l[-1]
# Out:
# (5+6j)

# %%
l[::-2]
# Out:
# [(5+6j), True, 54.565, 45]

# %%
l[::-1]
# Out:
# [(5+6j), False, True, 'kavan', 54.565, 546, 45]

# %%
l[::2]
# Out:
# [45, 54.565, True, (5+6j)]

# %%
s="pwskills"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s)
# Out:
# ['p', 'w', 's', 'k', 'i', 'l', 'l', 's']

# %%
list(s)=l
# Out:
#   Cell In[22], line 1
#     list(s)=l
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
list(s)+l
# Out:
# ['p',
#  'w',
#  's',
#  'k',
#  'i',
#  'l',
#  'l',
#  's',
#  45,
#  546,
#  54.565,
#  'kavan',
#  True,
#  False,
#  (5+6j)]

# %%
l
# Out:
# [45, 546, 54.565, 'kavan', True, False, (5+6j)]

# %%
l[3]
# Out:
# 'kavan'

# %%
l[3][0:2]
# Out:
# 'ka'

# %%
l[4][0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 l[4][0:2]
#
# TypeError: 'bool' object is not subscriptable

# %%
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
l
# Out:
# [45, 546, 54.565, 'kavan', True, False, (5+6j)]

# %%
l+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 l+5
#
# TypeError: can only concatenate list (not "int") to list

# %%
l1=["kana",3,4,5]

# %%
l+l1
# Out:
# [45, 546, 54.565, 'kavan', True, False, (5+6j), 'kana', 3, 4, 5]

# %%
l1*3
# Out:
# ['kana', 3, 4, 5, 'kana', 3, 4, 5, 'kana', 3, 4, 5]

# %%
l
# Out:
# [45, 546, 54.565, 'kavan', True, False, (5+6j)]

# %%
len(l)
# Out:
# 7

# %%
l.append(4)

# %%
l
# Out:
# [45, 546, 54.565, 'kavan', True, False, (5+6j), 4]

# %%
l.append
# Out:
# <function list.append(object, /)>

# %%
l.append(s)

# %%
s
# Out:
# 'pwskills'

# %%
l
# Out:
# [45, 546, 54.565, 'kavan', True, False, (5+6j), 4, 'pwskills']

# %%
l.append(l1)

# %%
l
# Out:
# [45,
#  546,
#  54.565,
#  'kavan',
#  True,
#  False,
#  (5+6j),
#  4,
#  'pwskills',
#  ['kana', 3, 4, 5]]

# %%
print(l)
# Out:
# [45, 546, 54.565, 'kavan', True, False, (5+6j), 4, 'pwskills', ['kana', 3, 4, 5]]

# %%
l[-1][1]
# Out:
# 3

# %%
l.extend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 l.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
l.extend("study")

# %%
l
# Out:
# [45,
#  546,
#  54.565,
#  'kavan',
#  True,
#  False,
#  (5+6j),
#  4,
#  'pwskills',
#  ['kana', 3, 4, 5],
#  's',
#  't',
#  'u',
#  'd',
#  'y']

# %%
 l.extend([3,4,5])

# %%
l
# Out:
# [45,
#  546,
#  54.565,
#  'kavan',
#  True,
#  False,
#  (5+6j),
#  4,
#  'pwskills',
#  ['kana', 3, 4, 5],
#  's',
#  't',
#  'u',
#  'd',
#  'y',
#  3,
#  4,
#  5]

# %%
l1
# Out:
# ['kana', 3, 4, 5]

# %%
l1.insert(0,"kumar")

# %%
l1
# Out:
# ['kumar', 'kana', 'kumar', 3, 4, 5]

# %%
l.insert(2,"alpa")

# %%
l1
# Out:
# ['kumar', 'kana', 'kumar', 3, 4, 5]

# %%
l
# Out:
# [45,
#  546,
#  'alpa',
#  54.565,
#  'kavan',
#  True,
#  False,
#  (5+6j),
#  4,
#  'pwskills',
#  ['kumar', 'kana', 'kumar', 3, 4, 5],
#  's',
#  't',
#  'u',
#  'd',
#  'y',
#  3,
#  4,
#  5]

# %%
l1.insert(2,[3,4,5,56])

# %%
l1
# Out:
# ['kumar', 'kana', [3, 4, 5, 56], 'kumar', 3, 4, 5]

# %%
l1.append(67)

# %%
l1
# Out:
# ['kumar', 'kana', [3, 4, 5, 56], 'kumar', 3, 4, 5, 67]

# %%
l1.insert(-1,45)

# %%
l1
# Out:
# ['kumar', 'kana', [3, 4, 5, 56], 'kumar', 3, 4, 5, 45, 67]

# %%
print(l)
# Out:
# [45, 546, 'alpa', 54.565, 'kavan', True, False, (5+6j), 4, 'pwskills', ['kumar', 'kana', [3, 4, 5, 56], 'kumar', 3, 4, 5, 45, 67], 's', 't', 'u', 'd', 'y', 3, 4, 5]

# %%
 l1
# Out:
# ['kumar', 'kana', [3, 4, 5, 56], 'kumar', 3, 4, 5, 45, 67]

# %%
l1.pop()
# Out:
# 67

# %%
l1
# Out:
# ['kumar', 'kana', [3, 4, 5, 56], 'kumar', 3, 4, 5, 45]

# %%
l1.pop(2)
# Out:
# [3, 4, 5, 56]

# %%
l1
# Out:
# ['kumar', 'kana', 'kumar', 3, 4, 5, 45]

# %%
l=[3,4,5,"kavan",[66,43635],8+6j]

# %%
l.reverse()

# %%
l
# Out:
# [(8+6j), [66, 43635], 'kavan', 5, 4, 3]

# %%
l
# Out:
# [(8+6j), [66, 43635], 'kavan', 5, 4, 3]

# %%
l.reverse()
print(l)
# Out:
# [3, 4, 5, 'kavan', [66, 43635], (8+6j)]

# %%
l[::-1]
# Out:
# [(8+6j), [66, 43635], 'kavan', 5, 4, 3]

# %%
l.srot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 l.srot()
#
# AttributeError: 'list' object has no attribute 'srot'

# %%
l2=[4,6,234,61,2144]

# %%
l2.sort()

# %%
l2
# Out:
# [4, 6, 61, 234, 2144]

# %%
l3=[34,"kavan",35,45,"kumar"]

# %%
l3.sort()
# Out:
#   Cell In[18], line 1
#     l3.sort()  1
#                ^
# SyntaxError: invalid syntax

# %%
#here comaprison operation perform so we can't different data type campersions .

# %%
l4=["kavan","pwskills","kumar","sadhguru","namskaram","nimisha"]

# %%
l4.sort()

# %%
l4
# Out:
# ['kavan', 'kumar', 'namskaram', 'nimisha', 'pwskills', 'sadhguru']

# %%
l4.sort(reverse=True)

# %%
l4
# Out:
# ['sadhguru', 'pwskills', 'nimisha', 'namskaram', 'kumar', 'kavan']

# %%
l4.index("nimisha")
# Out:
# 2

# %%
l5=[34,6575,"kavan","nimu",867.465,7+8j,"sadhguru"]

# %%
l5.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 l5.count()
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
l5.count(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 l5.count(a)
#
# NameError: name 'a' is not defined

# %%
s="kavan"

# %%
s[0]='N'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s[0]='N'
#
# TypeError: 'str' object does not support item assignment

# %%
l5[0] =300

# %%
l5
# Out:
# [300, 6575, 'kavan', 'nimu', 867.465, (7+8j), 'sadhguru']

# %%
s
# Out:
# 'kavan'

# %%
s.replace('k','a')
# Out:
# 'aavan'

# %%
s1="nimisha"

# %%
s1.replace('nim',' ')
# Out:
# ' isha'
