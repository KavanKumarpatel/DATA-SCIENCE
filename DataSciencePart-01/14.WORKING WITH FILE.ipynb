# %%
class pwskills:
    
    def __init__(self,course_price,course_name):
        
        self.__course_price=course_price
        self.course_name=course_name
        
        @property
        def course_price_access(self):
            return self.__course_price
        
        @course_price_access.setter
        def course_price_set(self,price):
            if price <= 3500:
                pass
            else :
                selfgggh

# %%
pw=pwskills(3500,"data science masters")

# %%
pw._pwskills__course_price
# Out:
# 3500

# %%
pw.course_name
# Out:
# 'data science masters'

# %%
pw.course_name
# Out:
# 'data science masters'

# %% [markdown]
# # working with files

# %%
f=open("test.txt",'w')

# %%
pwd
# Out:
# 'C:\\Users\\Rameshbhai patel\\Untitled Folder 1'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 1C92-5F7E
#
#  Directory of C:\Users\Rameshbhai patel\Untitled Folder 1
#
# 29-03-2024  21:02    <DIR>          .
# 29-03-2024  15:44    <DIR>          ..
# 29-03-2024  20:48    <DIR>          .ipynb_checkpoints
# 14-03-2024  20:49            51,895 1..PW   DATA SCIENCE MASTER(string,list).ipynb
# 25-03-2024  10:45            31,719 10.OOPS .ipynb
# 25-03-2024  11:19             4,002 11.DECORATOR.ipynb
# 25-03-2024  14:34            13,172 12.CLASS METHOD.ipynb
# 26-03-2024  23:32            10,908 13.STATIC METHOD.ipynb
# 29-03-2024  21:02             3,190 14.WORKING WITH FILE.ipynb
# 14-03-2024  15:08            10,786 2.TUPLE ,SET.ipynb
# 16-03-2024  21:34            25,535 3. DICT,IF ELIF ELSE (LOOP).ipynb
# 17-03-2024  21:02            27,759 4.FOR LOOP.ipynb
# 17-03-2024  22:03             3,368 5.while loop.ipynb
# 22-03-2024  17:55             4,899 6.Comprehension.ipynb
# ...

# %%
cd work
# Out:
# [WinError 2] The system cannot find the file specified: 'work'
# C:\Users\Rameshbhai patel\Untitled Folder 1

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 1C92-5F7E
#
#  Directory of C:\Users\Rameshbhai patel\Untitled Folder 1
#
# 29-03-2024  21:04    <DIR>          .
# 29-03-2024  15:44    <DIR>          ..
# 29-03-2024  20:48    <DIR>          .ipynb_checkpoints
# 14-03-2024  20:49            51,895 1..PW   DATA SCIENCE MASTER(string,list).ipynb
# 25-03-2024  10:45            31,719 10.OOPS .ipynb
# 25-03-2024  11:19             4,002 11.DECORATOR.ipynb
# 25-03-2024  14:34            13,172 12.CLASS METHOD.ipynb
# 26-03-2024  23:32            10,908 13.STATIC METHOD.ipynb
# 29-03-2024  21:04             4,948 14.WORKING WITH FILE.ipynb
# 14-03-2024  15:08            10,786 2.TUPLE ,SET.ipynb
# 16-03-2024  21:34            25,535 3. DICT,IF ELIF ELSE (LOOP).ipynb
# 17-03-2024  21:02            27,759 4.FOR LOOP.ipynb
# 17-03-2024  22:03             3,368 5.while loop.ipynb
# 22-03-2024  17:55             4,899 6.Comprehension.ipynb
# ...

# %%
f.write("this is my first file to write")
# Out:
# 30

# %%
f.close()

# %%
f=open("test.txt",'w')

# %%
f.write("this is my file")
# Out:
# 15

# %%
f.close()

# %%
f=open("test.txt",'a')

# %%
f.write("With an average salary of $139,480, they explore, analyze, visualize, and organize data for the companies. They analyze the complex data sets and processes to find patterns for decision making and predicting the business and drive strategies.")
# Out:
# 242

# %%
f.close()

# %%
f=open("test.txt",'r')

# %%
f.read()
# Out:
# 'this is my fileWith an average salary of $139,480, they explore, analyze, visualize, and organize data for the companies. They analyze the complex data sets and processes to find patterns for decision making and predicting the business and drive strategies.'

# %%
data=open("test.txt",'r')

# %%
data
# Out:
# <_io.TextIOWrapper name='test.txt' mode='r' encoding='cp1252'>

# %%
 data.readline()
# Out:
# 'this is my fileWith an average salary of $139,480, they explore, analyze, visualize, and organize data for the companies. They analyze the complex data sets and processes to find patterns for decision making and predicting the business and drive strategies.'

# %%
data.readlines()
# Out:
# []

# %%
data.seek(10)
# Out:
# 10

# %%
data.read()
# Out:
# ' fileWith an average salary of $139,480, they explore, analyze, visualize, and organize data for the companies. They analyze the complex data sets and processes to find patterns for decision making and predicting the business and drive strategies.'

# %%
data.read()
# Out:
# ''

# %%
data1=open("test.txt",'r')

# %%
for i in data1:
    print(i)
# Out:
# this is my fileWith an average salary of $139,480, they explore, analyze, visualize, and organize data for the companies. They analyze the complex data sets and processes to find patterns for decision making and predicting the business and drive strategies.

# %%
import os

# %%
os.path.getsize("test.txt")
# Out:
# 257

# %%
os.remove("test.txt")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 os.remove("test.txt")
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'test.txt'

# %%
f=open("test1.txt",'w')

# %%
f.write("this is new file ")
# Out:
# 17

# %%
f.close()

# %%
os.rename("test1.txt","new.txt")

# %%
import shutil

# %%
shutil.copy("new.txt","copy_new.txt")
# Out:
# 'copy_new.txt'

# %%
with open("new.txt","r") as f:
    print(f.read())
# Out:
# this is new file

# %% [markdown]
# # READING AND WRITING

# %%
data={
    "name":"kavan",
    "mail id":"kavan3@gmail.com",
    "phone number":923876412,
    "subject":["data science ","big data","data analytics"]
}

# %%
import json

# %%
with open("data.json","w") as f:
    json.dump(data,f)

# %%
with open("data.json","r") as f:
    data1=json.load(f)

# %%
data1
# Out:
# {'name': 'kavan',
#  'mail id': 'kavan3@gmail.com',
#  'phone number': 923876412,
#  'subject': ['data science ', 'big data', 'data analytics']}

# %%
data1['subject'][1]
# Out:
# 'big data'

# %%
import csv

# %%
data =[["name","mail_id","phone_number"],
       ["kavan","kavan456@gmail.com",982374123],
       ["nimisha","nimisha8723@gmail.com",92342341]
       
]

# %%
with open("data.csv",'w') as f:
    writer=csv.writer(f)
    
    for i in data:
        writer.writerow(i)

# %%
with open("data.csv",'r') as f:
    read_data=csv.reader(f)
    
    
    for i in read_data:
        print(i)
# Out:
# ['name', 'mail_id', 'phone_number']
# []
# ['kavan', 'kavan456@gmail.com', '982374123']
# []
# ['nimisha', 'nimisha8723@gmail.com', '92342341']
# []

# %%
 with open("test4.bin","wb") as f:
        f.write(b"\x01\x02\x03934875")

# %%
with open("test4.bin",'rb') as f:
    print(f.read())
# Out:
# b'\x01\x02\x03934875'

# %% [markdown]
# # BUFFERED READ AND WRITE

# %%
import io

# %%
with open("test5.txt",'wb') as f:
    file=io.BufferedWriter(f)
    
    file.write(b"This is my first line")
    file.write(b"This is my second line")

# %%
##yaha par file to banjayegi lekin data nai milega file khai hogi

# %%
with open("test5.txt",'wb') as f:
    file=io.BufferedWriter(f)
    
    file.write(b"This is my first line In computer science and computers, the term artificial intelligence has played a very prominent role. The term has become more popular due to recent advances in Artificial Intelligence and Machine Learning..\n")
    file.write(b"This is my second line")
    file.flush()

# %%
with open("text5.txt",'rb') as f:
    
    file=io.BufferedReader(f)
    data=file.read(100)
    print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 with open("text5.txt",'rb') as f:
#       3     file=io.BufferedReader(f)
#       4     data=file.read(100)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'text5.txt'
