# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,10, 200)

# %%
x
# Out:
# array([ 0.        ,  0.05025126,  0.10050251,  0.15075377,  0.20100503,
#         0.25125628,  0.30150754,  0.35175879,  0.40201005,  0.45226131,
#         0.50251256,  0.55276382,  0.60301508,  0.65326633,  0.70351759,
#         0.75376884,  0.8040201 ,  0.85427136,  0.90452261,  0.95477387,
#         1.00502513,  1.05527638,  1.10552764,  1.15577889,  1.20603015,
#         1.25628141,  1.30653266,  1.35678392,  1.40703518,  1.45728643,
#         1.50753769,  1.55778894,  1.6080402 ,  1.65829146,  1.70854271,
#         1.75879397,  1.80904523,  1.85929648,  1.90954774,  1.95979899,
#         2.01005025,  2.06030151,  2.11055276,  2.16080402,  2.21105528,
#         2.26130653,  2.31155779,  2.36180905,  2.4120603 ,  2.46231156,
#         2.51256281,  2.56281407,  2.61306533,  2.66331658,  2.71356784,
#         2.7638191 ,  2.81407035,  2.86432161,  2.91457286,  2.96482412,
#         3.01507538,  3.06532663,  3.11557789,  3.16582915,  3.2160804 ,
# ...

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.05023011,  0.10033341,  0.15018339,  0.19965422,
#         0.24862099,  0.29696008,  0.34454944,  0.39126893,  0.43700061,
#         0.481629  ,  0.52504145,  0.56712835,  0.60778345,  0.6469041 ,
#         0.68439153,  0.72015112,  0.75409257,  0.78613019,  0.8161831 ,
#         0.84417544,  0.87003651,  0.89370105,  0.91510929,  0.9342072 ,
#         0.95094655,  0.96528509,  0.97718662,  0.98662108,  0.99356467,
#         0.99799984,  0.99991541,  0.99930653,  0.99617474,  0.99052796,
#         0.98238043,  0.97175273,  0.95867168,  0.94317032,  0.92528777,
#         0.90506919,  0.88256563,  0.85783388,  0.8309364 ,  0.80194109,
#         0.77092115,  0.7379549 ,  0.70312557,  0.66652108,  0.62823386,
#         0.58836056,  0.54700186,  0.50426216,  0.46024937,  0.41507461,
#         0.36885193,  0.32169803,  0.27373195,  0.22507478,  0.17584939,
#         0.12618003,  0.07619211,  0.02601183, -0.02423412, -0.07441889,
# ...

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("this is my x data")
plt.ylabel("this is my y data")
plt.title("this is my title")
plt.show()

# %%
w = np.random.rand(50)
z = np.random.rand(50)
plt.scatter(w,z)

# %%
z
# Out:
# array([0.7358642 , 0.20099815, 0.62010062, 0.93278585, 0.60404019,
#        0.19634438, 0.51064302, 0.75581278, 0.83272623, 0.99787375,
#        0.35857069, 0.65317655, 0.41989851, 0.17107596, 0.25984086,
#        0.36822116, 0.51033308, 0.04294431, 0.56864404, 0.00344964,
#        0.34113251, 0.58184782, 0.49938541, 0.18851445, 0.40382954,
#        0.0509107 , 0.43995314, 0.31087244, 0.64732035, 0.65274195,
#        0.26577222, 0.52740239, 0.39380229, 0.92310089, 0.55248763,
#        0.47024758, 0.60360856, 0.14699294, 0.38805492, 0.82780597,
#        0.53288746, 0.15886006, 0.06596935, 0.58962571, 0.98052737,
#        0.9271175 , 0.9255468 , 0.29322306, 0.95308079, 0.53784441])

# %%
w
# Out:
# array([0.3444648 , 0.81392875, 0.61329079, 0.46871902, 0.61360106,
#        0.72890893, 0.15787971, 0.63418985, 0.07335601, 0.8666618 ,
#        0.85821158, 0.78759879, 0.75607855, 0.4895642 , 0.19955153,
#        0.46761399, 0.17273652, 0.67232954, 0.64501919, 0.06987491,
#        0.97730901, 0.31285925, 0.47996122, 0.03239004, 0.45395874,
#        0.65355344, 0.04006421, 0.96753052, 0.22134067, 0.15012914,
#        0.08301727, 0.3132323 , 0.51836062, 0.03836093, 0.14399714,
#        0.2741262 , 0.88758495, 0.74124639, 0.40935878, 0.59391643,
#        0.55311877, 0.74464611, 0.08497656, 0.08236921, 0.56868446,
#        0.45801059, 0.51460285, 0.03879635, 0.31163644, 0.97457644])

# %%
calours = np.random.rand(50)
plt.scatter(z,w, c = calours)

# %%
calours = np.random.rand(50)
sizes = np.random.rand(50)
plt.scatter(z,w, c = calours,s= sizes)

# %%
calours = np.random.rand(50)
sizes =1000* np.random.rand(50)
plt.scatter(z,w, c = calours,s= sizes)

# %%
calours = np.random.rand(50)
sizes = 1000*np.random.rand(50)
plt.scatter(z,w, c = calours,s= sizes , alpha =.5)

# %%
calours = np.random.rand(50)
sizes = 1000*np.random.rand(50)
plt.scatter(z,w, c = calours,s= sizes, alpha =.4)
plt.xlabel("xlabel")
plt.ylabel("ylabel")
plt.title("Random Data")
# Out:
# Text(0.5, 1.0, 'Random Data')

# %%
x = ['a' , 'b' , 'c' , 'd', 'e']

# %%
y = np.random.rand(5)

# %%
plt.bar(x,y)
plt.xlabel("x axis")
plt.ylabel("y label")
plt.title("bar plot")
# Out:
# Text(0.5, 1.0, 'bar plot')

# %%
y
# Out:
# array([0.29671391, 0.17300231, 0.16684396, 0.52032371, 0.89235921])

# %%
plt.barh(x,y)
plt.xlabel("x axis")
plt.ylabel("y label")
plt.title("bar plot")
# Out:
# Text(0.5, 1.0, 'bar plot')

# %%
p = np.linspace(0, 10, 200)
q = np.sin(p)

# %%
p
# Out:
# array([ 0.        ,  0.05025126,  0.10050251,  0.15075377,  0.20100503,
#         0.25125628,  0.30150754,  0.35175879,  0.40201005,  0.45226131,
#         0.50251256,  0.55276382,  0.60301508,  0.65326633,  0.70351759,
#         0.75376884,  0.8040201 ,  0.85427136,  0.90452261,  0.95477387,
#         1.00502513,  1.05527638,  1.10552764,  1.15577889,  1.20603015,
#         1.25628141,  1.30653266,  1.35678392,  1.40703518,  1.45728643,
#         1.50753769,  1.55778894,  1.6080402 ,  1.65829146,  1.70854271,
#         1.75879397,  1.80904523,  1.85929648,  1.90954774,  1.95979899,
#         2.01005025,  2.06030151,  2.11055276,  2.16080402,  2.21105528,
#         2.26130653,  2.31155779,  2.36180905,  2.4120603 ,  2.46231156,
#         2.51256281,  2.56281407,  2.61306533,  2.66331658,  2.71356784,
#         2.7638191 ,  2.81407035,  2.86432161,  2.91457286,  2.96482412,
#         3.01507538,  3.06532663,  3.11557789,  3.16582915,  3.2160804 ,
# ...

# %%
q
# Out:
# array([ 0.        ,  0.05023011,  0.10033341,  0.15018339,  0.19965422,
#         0.24862099,  0.29696008,  0.34454944,  0.39126893,  0.43700061,
#         0.481629  ,  0.52504145,  0.56712835,  0.60778345,  0.6469041 ,
#         0.68439153,  0.72015112,  0.75409257,  0.78613019,  0.8161831 ,
#         0.84417544,  0.87003651,  0.89370105,  0.91510929,  0.9342072 ,
#         0.95094655,  0.96528509,  0.97718662,  0.98662108,  0.99356467,
#         0.99799984,  0.99991541,  0.99930653,  0.99617474,  0.99052796,
#         0.98238043,  0.97175273,  0.95867168,  0.94317032,  0.92528777,
#         0.90506919,  0.88256563,  0.85783388,  0.8309364 ,  0.80194109,
#         0.77092115,  0.7379549 ,  0.70312557,  0.66652108,  0.62823386,
#         0.58836056,  0.54700186,  0.50426216,  0.46024937,  0.41507461,
#         0.36885193,  0.32169803,  0.27373195,  0.22507478,  0.17584939,
#         0.12618003,  0.07619211,  0.02601183, -0.02423412, -0.07441889,
# ...

# %%
plt.plot(p,q)
plt.xlabel("This is my x Data")
plt.ylabel("this is my y Data")
plt.title("This is my title")
plt.show()

# %%
plt.plot(p,q, '--r')
plt.xlabel("This is my x Data")
plt.ylabel("this is my y Data")
plt.title("This is my title")
plt.show()

# %%
plt.plot(p,q,'--b')
plt.xlabel("This is my x Data")
plt.ylabel("this is my y Data")
plt.title("This is my title")
plt.show()

# %%
"""ye --b wo blue dash line plot hone wali Hain aur --r me bhi yahi hoga red aayega  """
# Out:
# 'ye --b wo blue dash line plot hone wali Hain aur --r me bhi yahi hoga red aayega  '

# %%
plt.figure(figsize(8,4))
plt.plot(p,q,'--b')
plt.xlabel("This is my x Data")
plt.ylabel("this is my y Data")
plt.title("This is my title")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 plt.figure(figsize(8,4))
#       2 plt.plot(p,q,'--b')
#       3 plt.xlabel("This is my x Data")
#
# NameError: name 'figsize' is not defined

# %%
x= np.random.rand(50)
y=np.random.rand(50)
colurs = np.random.rand(50)
sizes = 1000*np.random.rand(50)
plt.scatter(x,y,c='b',s= sizes, alpha = .5)
plt.xlabel("x axis")
plt.ylabel("y  axis")
plt.title("random data")
# Out:
# Text(0.5, 1.0, 'random data')

# %%
a= np.random.rand(50)
b=np.random.rand(50)
colurs = np.random.rand(50)
sizes = 1000*np.random.rand(50)
plt.scatter(a,b,c='#A6D13',s= sizes, alpha = .5)
plt.alabel("x axis")
plt.blabel("y  axis")
plt.title("random data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:4433, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4432 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4433     colors = mcolors.to_rgba_array(c)
#    4434 except (TypeError, ValueError) as err:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\colors.py:471, in to_rgba_array(c, alpha)
#     470 if isinstance(c, str):
# --> 471     raise ValueError(f"{c!r} is not a valid color value.")
#     473 if len(c) == 0:
#
# ValueError: '#A6D13' is not a valid color value.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 5
#       3 colurs = np.random.rand(50)
#       4 sizes = 1000*np.random.rand(50)
# ...

# %%
x= np.random.rand(50)
y=np.random.rand(50)
colurs = np.random.rand(50)
sizes = 1000*np.random.rand(50)
plt.scatter(x,y,c='r',s= sizes, alpha = .5, marker = 'v')
plt.xlabel("x axis")
plt.ylabel("y  axis")
plt.title("random data")
# Out:
# Text(0.5, 1.0, 'random data')

# %%
x= [4,5,6,7,8,9]
y= [1,2,3,10,11,12]
plt.plot(x,y)
plt.show()

# %%
s= [1,2,3,4,5,6]
t= [23,45,65,121,2,6]
plt.scatter(s,t)
plt.show()

# %%
data = [1,2,3,4,2,4,54,45,3,23]

# %%
""" yaha par numbe rkitni  repeat ho raha hain  uski freqency ko bataye"""
# Out:
# ' yaha par numbe rkitni  repeat ho raha hain  uski freqency ko bataye'

# %%
plt.hist(data)
plt.show()

# %%
x= [4,5,6,7]
y= [34,45,23,21]
colour = ['red','#5CF0CD','green','#CC6CE7']
plt.scatter(x,y,c=colour)
plt.show()
