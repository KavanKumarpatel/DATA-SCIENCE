# %%
# !pip

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://Kavankumar:Kavankumar@cluster0.vjk4que.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pymongo.mongo_client import MongoClient
#       2 from pymongo.server_api import ServerApi
#       4 uri = "mongodb+srv://Kavankumar:Kavankumar@cluster0.vjk4que.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
#
# File ~\anaconda3\Lib\site-packages\pymongo\__init__.py:77
#      74 __version__ = version = get_version_string()
#      75 """Current version of PyMongo."""
# ---> 77 from pymongo.collection import ReturnDocument
#      78 from pymongo.common import (MIN_SUPPORTED_WIRE_VERSION,
#      79                             MAX_SUPPORTED_WIRE_VERSION)
#      80 from pymongo.cursor import CursorType
#
# File ~\anaconda3\Lib\site-packages\pymongo\collection.py:21
#      18 import datetime
#      19 import warnings
# ---> 21 from bson.code import Code
# ...

# %%
mongodb+srv://Kavankumar: Kavankumar@cluster0.vjk4que.mongodb.net/?
        retryWrites=true&w=majority&appName=Cluster0
# Out:
#   Cell In[4], line 1
#     mongodb+srv://Kavankumar: Kavankumar@cluster0.vjk4que.mongodb.net/?
#                ^
# SyntaxError: invalid syntax

# %%
mongodb+srv://Kavankumar:Kavankumar@cluster0.vjk4que.mongodb.net/
# Out:
#   Cell In[8], line 1
#     mongodb+srv://Kavankumar:Kavankumar@cluster0.vjk4que.mongodb.net/
#                ^
# SyntaxError: invalid syntax

# %%
# !pip install pymongo

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://Kavankumar:Kavankumar@cluster0.vjk4que.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from pymongo.mongo_client import MongoClient
#       2 from pymongo.server_api import ServerApi
#       4 uri = "mongodb+srv://Kavankumar:Kavankumar@cluster0.vjk4que.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
#
# File ~\anaconda3\Lib\site-packages\pymongo\__init__.py:77
#      74 __version__ = version = get_version_string()
#      75 """Current version of PyMongo."""
# ---> 77 from pymongo.collection import ReturnDocument
#      78 from pymongo.common import (MIN_SUPPORTED_WIRE_VERSION,
#      79                             MAX_SUPPORTED_WIRE_VERSION)
#      80 from pymongo.cursor import CursorType
#
# File ~\anaconda3\Lib\site-packages\pymongo\collection.py:22
#      19 import warnings
#      21 from bson.code import Code
# ---> 22 from bson.objectid import ObjectId
# ...

# %%
mongodb+srv://Kavankumar: Kavankumar@cluster0.vjk4que.mongodb.net/?
        retryWrites=true&w=majority&appName=Cluster0
# Out:
#   Cell In[13], line 1
#     mongodb+srv://Kavankumar: Kavankumar@cluster0.vjk4que.mongodb.net/?
#                ^
# SyntaxError: invalid syntax

# %%
from collections.abc import MutableMapping
from pymongo import MongoClient
connection_string = "mongodb+srv://Kavankumar:Kavankumar@cluster0.vjk4que.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"


client = MongoClient(connection_string)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 2
#       1 from collections.abc import MutableMapping
# ----> 2 from pymongo import MongoClient
#       3 connection_string = "mongodb+srv://Kavankumar:Kavankumar@cluster0.vjk4que.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
#       6 client = MongoClient(connection_string)
#
# File ~\anaconda3\Lib\site-packages\pymongo\__init__.py:77
#      74 __version__ = version = get_version_string()
#      75 """Current version of PyMongo."""
# ---> 77 from pymongo.collection import ReturnDocument
#      78 from pymongo.common import (MIN_SUPPORTED_WIRE_VERSION,
#      79                             MAX_SUPPORTED_WIRE_VERSION)
#      80 from pymongo.cursor import CursorType
#
# File ~\anaconda3\Lib\site-packages\pymongo\collection.py:22
#      19 import warnings
#      21 from bson.code import Code
# ...

# %%
from collections.abc import MutableMapping  # Import MutableMapping explicitly
from pymongo import MongoClient

# MongoDB connection string
connection_string = "mongodb+srv://Kavankumar:Kavankumar@cluster0.vjk4que.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a MongoDB client
client = MongoClient(connection_string)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 2
#       1 from collections.abc import MutableMapping  # Import MutableMapping explicitly
# ----> 2 from pymongo import MongoClient
#       4 # MongoDB connection string
#       5 connection_string = "mongodb+srv://Kavankumar:Kavankumar@cluster0.vjk4que.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
#
# File ~\anaconda3\Lib\site-packages\pymongo\__init__.py:77
#      74 __version__ = version = get_version_string()
#      75 """Current version of PyMongo."""
# ---> 77 from pymongo.collection import ReturnDocument
#      78 from pymongo.common import (MIN_SUPPORTED_WIRE_VERSION,
#      79                             MAX_SUPPORTED_WIRE_VERSION)
#      80 from pymongo.cursor import CursorType
#
# File ~\anaconda3\Lib\site-packages\pymongo\collection.py:22
#      19 import warnings
# ...

# %%
from pymongo import MongoClient

client=MongoClient('mongodb+srv://Kavankumar:Kavankumar@cluster0.vjk4que.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
db=client['db1']
collection=db['youtube']
document={"name":"kavanpatel","city":"visnagar"}
insert_doc=collection.insert_one(document)



print("inserted document sucessfully id:(insert_doc.inserted_id)")
client.close()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from pymongo import MongoClient
#       3 client=MongoClient('mongodb+srv://Kavankumar:Kavankumar@cluster0.vjk4que.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
#       4 db=client['db1']
#
# File ~\anaconda3\Lib\site-packages\pymongo\__init__.py:77
#      74 __version__ = version = get_version_string()
#      75 """Current version of PyMongo."""
# ---> 77 from pymongo.collection import ReturnDocument
#      78 from pymongo.common import (MIN_SUPPORTED_WIRE_VERSION,
#      79                             MAX_SUPPORTED_WIRE_VERSION)
#      80 from pymongo.cursor import CursorType
#
# File ~\anaconda3\Lib\site-packages\pymongo\collection.py:22
#      19 import warnings
#      21 from bson.code import Code
# ---> 22 from bson.objectid import ObjectId
# ...
