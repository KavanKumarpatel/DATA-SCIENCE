# %%
#Mean()

# %%
age = [12, 21,34,45,27,32,67,45,76,57]

# %%
import numpy as np

# %%
np.mean(age)
# Out:
# 41.6

# %%
weights = [54,45,67,87,76,77,23,45,33,45]

# %%
np.mean(weights)
# Out:
# 55.2

# %%
import seaborn as sns
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
np.mean(df['total_bill'])
# Out:
# 19.78594262295082

# %%
#median

# %%
np.median(age)
# Out:
# 39.5

# %%
age
# Out:
# [12, 21, 34, 45, 27, 32, 67, 45, 76, 57]

# %%
age.insert(12,145)

# %%
age
# Out:
# [12, 21, 34, 45, 27, 32, 67, 45, 76, 57, 12, 7, 145]

# %%
np.mean(age)
# Out:
# 44.61538461538461

# %%
np.median(age)
# Out:
# 34.0

# %%
age.pop()
# Out:
# 145

# %%
age.insert(13,688)

# %%
age
# Out:
# [12, 21, 34, 45, 27, 32, 67, 45, 76, 57, 12, 7, 688]

# %%
np.mean(age)
# Out:
# 86.38461538461539

# %%
np.median(age)
# Out:
# 34.0

# %%
"""MEdian hum vaha par add karte hain jaha par outlier hote hain yaha par outlier 688 hain """
# Out:
# 'MEdian hum vaha par add karte hain jaha par outlier hote hain yaha par outlier 688 hain '

# %%
from scipy import stats

# %%
stats.mode(age)
# Out:
# ModeResult(mode=12, count=2)

# %%
"""yaha par frequency batata hain to karte rehna """
# Out:
# 'yaha par frequency batata hain to karte rehna '
